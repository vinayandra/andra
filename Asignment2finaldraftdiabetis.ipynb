# %%
#import libraries
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("E:\\race\diabetisdata.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import matplotlib.pyplot as plt
X = df['Pregnancies']
plt.hist(X)
plt.show()

# %%
Y = df['Glucose']
plt.hist(Y)
plt.show()

# %%
Z = df['BloodPressure']
plt.hist(Z)
plt.show()

# %%
A = df['SkinThickness']
plt.hist(A)
plt.show()

# %%
B = df['Insulin']
plt.hist(B)
plt.show()

# %%
C = df['BMI']
plt.hist(C)
plt.show()

# %%
D= df['Age']
plt.hist(D)
plt.show()

# %%
plt.hist(z)
plt.show()

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
#Scatter Plot BMI and Blood Glucose
import matplotlib.pyplot as plt
x=df['BMI']
y=df['Glucose']
z=df['Outcome']
colors = {0:'red' , 1:'blue'}
plt.scatter(x,y , c=z.apply(lambda x : colors[x]))
plt.xlabel ('BMI')
plt.ylabel ('Glucose')
plt.show()

# %%
#Scatter Plot BMI and BloodPressure
import matplotlib.pyplot as plt
x=df['BMI']
y=df['BloodPressure']
z=df['Outcome']
colors = {0:'red' , 1:'blue'}
plt.scatter(x,y , c=z.apply(lambda x : colors[x]))
plt.xlabel ('BMI')
plt.ylabel ('BloodPressure')
plt.show()

# %%
#Scatter Plot BloodPressure and Glucose
import matplotlib.pyplot as plt
x=df['BloodPressure']
y=df['Glucose']
z=df['Outcome']
colors = {0:'red' , 1:'blue'}
plt.scatter(x,y , c=z.apply(lambda x : colors[x]))
plt.xlabel ('BloodPressure')
plt.ylabel ('Glucose')
plt.show()

# %%
df['GlucoseBin'] = np.where(df['Glucose'] <=140,'<=140')
y=df['Glucose']
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-22-2725dbfac13c> in <module>()
# ----> 1 df['GlucoseBin'] = np.where(df['Glucose'] <=140,'<=140')
#
# ValueError: either both or neither of x and y should be given

# %%
import numpy as np
df['GluBin'] = np.where(df['Glucose'] <=140,'<=140', (np.where(df['Glucose']> 140 ,'>140')))
df.Glubin()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-27-0c1480197d41> in <module>()
#       1 import numpy as np
# ----> 2 df['GluBin'] = np.where(df['Glucose'] <=140,'<=140', (np.where(df['Glucose']> 140 ,'>140')))
#       3 df.Glubin()
#
# ValueError: either both or neither of x and y should be given

# %%
import numpy as np
df['GluBin'] = np.where(df['Glucose'] <=160,'<=160', (np.where(df['Glucose'] >160 ,'>160', '0')))
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome GluBin
# 0                     0.627   50        1  <=160
# 1                     0.351   31        0  <=160
# 2                     0.672   32        1   >160
# 3                     0.167   21        0  <=160
# 4                     2.288   33        1  <=160

# %%
#Pivot table with binned data for confusion matrix of full data set
pd.pivot_table(df, values="Glucose", index=["GluBin"], columns="Outcome", aggfunc = "count",fill_value=0)
# Out:
# Outcome    0    1
# GluBin
# <=160    482  185
# >160      18   83

# %%
#Create Training Data Set from Full Dataset with 70% observations
train, test = np.split(df.sample(frac=1), [int(.7*len(df))])

# %%
train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 578           10      133             68              0        0  27.0
# 511            0      139             62             17      210  22.1
# 160            4      151             90             38        0  29.7
# 80             3      113             44             13        0  22.4
# 457            5       86             68             28       71  30.2
# 656            2      101             58             35       90  21.8
# 200            0      113             80             16        0  31.0
# 483            0       84             82             31      125  38.2
# 425            4      184             78             39      277  37.0
# 356            1      125             50             40      167  33.3
# 206            8      196             76             29      280  37.5
# 536            0      105             90              0        0  29.6
# ...

# %%
# Explore Correlation of Training Data Set
train.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.148827       0.148418      -0.102278
# Glucose                      0.148827  1.000000       0.142581       0.034741
# BloodPressure                0.148418  0.142581       1.000000       0.219951
# SkinThickness               -0.102278  0.034741       0.219951       1.000000
# Insulin                     -0.096698  0.308479       0.076346       0.430706
# BMI                          0.050847  0.240251       0.259486       0.364759
# DiabetesPedigreeFunction    -0.062504  0.140012       0.030304       0.214675
# Age                          0.548540  0.224634       0.225259      -0.156422
# Outcome                      0.226570  0.488832       0.090493       0.027236
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.096698  0.050847                 -0.062504
# ...

# %%
#Analyzing Train Data considering Glucose and BMI
g = sns.pairplot(train , vars=["Glucose", "BMI"] , hue="Outcome" , palette="husl" , size = 5)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-37-1bd0fde93b76> in <module>()
#       1 #Analyzing Train Data considering Glucose and BMI
# ----> 2 g = sns.pairplot(train , vars=["Glucose", "BMI"] , hue="Outcome" , palette="husl" , size = 5)
#
# NameError: name 'sns' is not defined

# %%
# Explore correlations between Glucose and BMI
import seaborn as sns; sns.set(style="ticks", color_codes=True)

# %%
#Analyzing Train Data considering Glucose and BMI
g = sns.pairplot(train , vars=["Glucose", "BMI"] , hue="Outcome" , palette="husl" , size = 5)

# %%
# Glucose Confusion Matrix on Training Data Set
pd.pivot_table(train, values="Glucose", index=["GluBin"], columns="Outcome", aggfunc = "count",fill_value=0)
# Out:
# Outcome    0    1
# GluBin
# <=160    338  124
# >160      13   62

# %%
# Glucose Confusion Matrix on Test Data Set
pd.pivot_table(test, values="Glucose", index=["GluBin"], columns="Outcome", aggfunc = "count",fill_value=0)
# Out:
# Outcome    0   1
# GluBin
# <=160    144  61
# >160       5  21

# %%
#Discover Rules for BMI to predict Outcome of Diabetes on full data set
#Bin variables Bin 1 : BMI > 30 - Diabetic and Bin 2 : BMI <=160 - Non Diabetic
import numpy as np
df['BMIBin'] = np.where(df['BMI'] <=30,'<=30', (np.where(df['BMI'] >30 ,'>30', '0')))
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome GluBin BMIBin
# 0                     0.627   50        1  <=160    >30
# 1                     0.351   31        0  <=160   <=30
# 2                     0.672   32        1   >160   <=30
# 3                     0.167   21        0  <=160   <=30
# 4                     2.288   33        1  <=160    >30

# %%
#Pivot table with binned data for confusion matrix of full data set
#BMI Confusion Matrix on Full Data Set
pd.pivot_table(df, values="BMI", index=["BMIBin"], columns="Outcome", aggfunc = "count",fill_value=0)
# Out:
# Outcome    0    1
# BMIBin
# <=30     250   53
# >30      250  215

# %%
BMI <= 30 are nondiabetic. Accuracy level 83%. BMI > 30 are Diabetic. Accuracy level 46%
# Out:
#   File "<ipython-input-46-81494beb3b25>", line 1
#     BMI <= 30 are nondiabetic. Accuracy level 83%. BMI > 30 are Diabetic. Accuracy level 46%
#                 ^
# SyntaxError: invalid syntax

# %%
#Create Training Data Set from Full Dataset with 70% observations
train, test = np.split(df.sample(frac=1), [int(.7*len(df))])

# %%
# BMI Confusion Matrix on Training Data Set
pd.pivot_table(train, values="BMI", index=["BMIBin"], columns="Outcome", aggfunc = "count",fill_value=0)
# Out:
# Outcome    0    1
# BMIBin
# <=30     174   37
# >30      179  147

# %%
BMI <= 30 are nondiabetic. Accuracy level 82%. BMI > 30 are Diabetic. Accuracy level 47%
# Out:
#   File "<ipython-input-49-6282985128ff>", line 1
#     BMI <= 30 are nondiabetic. Accuracy level 82%. BMI > 30 are Diabetic. Accuracy level 47%
#                 ^
# SyntaxError: invalid syntax

# %%
# BMI Confusion Matrix on Test Data Set
pd.pivot_table(test, values="BMI", index=["BMIBin"], columns="Outcome", aggfunc = "count",fill_value=0)
# Out:
# Outcome   0   1
# BMIBin
# <=30     76  16
# >30      71  68

# %%
BMI <= 30 are nondiabetic. Accuracy level 84%. BMI > 30 are Diabetic. Accuracy level 44%
